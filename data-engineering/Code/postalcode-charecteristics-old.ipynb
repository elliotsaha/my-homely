# %%
import pandas as pd

# %%
datadictionary = {}

# %%
datadictionarylong = {}

# %% [markdown]
# 0th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Population', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: 'Population' + ' ' + x if 'population' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 0       PP_TOT  Total - Age groups and average age of the popu...      52
# 1      PP_0_14                           Population 0 to 14 years      15
# 2       PP_0_4                            Population 0 to 4 years      16
# 3       PP_5_9                            Population 5 to 9 years      16
# 4     PP_10_14                          Population 10 to 14 years      18
# ..         ...                                                ...     ...
# 88    PP_NMRCL   Population Not married and not living common law      39
# 89      PP_NMR                           Population Never married      17
# 90      PP_SEP                               Population Separated      13
# 91  PP_DIVORCE                                Population Divorced      12
# 92    PP_WIDOW                                 Population Widowed      11
#
#                                   Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# PP_PP_MED
# Median age of total population: half of the population below this age, the other half above this age.
#
# PP_FM_MED
# Median age of female population: half of the female population below this age, the other half above this age.
#
# PP_M_MED
# Median age of male population: half of the male population below this age, the other half above this age.

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# PP_PP_MED
# Median age of total population
#
# PP_FM_MED
# Median age of female population
#
# PP_M_MED
# Median age of male population

# %% [markdown]
# 1st Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Family', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#      Variable                                        Description  length  \
# 0      FM_TOT  Total - Census families in private households:...     374
# 1       FM_2P                  Number of families with 2 persons      35
# 2       FM_3P                  Number of families with 3 persons      35
# 3       FM_4P                  Number of families with 4 persons      35
# 4      FM_5_P          Number of families with 5 or more persons      43
# 5    FM_AVG_P        Average number of persons per census family      43
# 6    FM_TOT_S  Total number of census families in private hou...      53
# 7       FM_CP  Total couple families by family structure and ...     281
# 8   FM_CPNKID                           Without children at home      34
# 9   FM_CPKIDS                              With children at home      31
# 10  FM_CP1KID                                            1 child      20
# 11  FM_CP2KID                                         2 children      23
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# FM_TOT
# Total - Census families in private households: Census family refers to a married couple (with or without children of either or both spouses), a couple living common-law (with or without children of either or both partners) or a lone parent of any marital status, with at least one child living in the same dwelling. A couple living common-law may be of opposite or same sex.
#
# FM_CP
# Total couple families by family structure and number of children: A couple family refers to the classification of census families into married couples (with or without children of either or both spouses), common-law couples (with or without children of either or both partners).
#
# FM_CL
# Common-law couples:  two people living together as a couple but not legally married to each other. They may be of opposite sex or of the same sex.
#
# FM_CH
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# FM_TOT
# Total - Census families in private households
#
# FM_CP
# Total couple families by family structure and number of children
#
# FM_CL
# Common-law couples
#
# FM_CH
# Total number of children at home
#
# FM_AVCH
# Average number of children at home per census family
#
# FM_PH_P
# Total number of persons in private households by living arrangements
#
# FM_NF_P
# Number of non-family persons

# %%
# datadictionary['FM_TOT'] == 'Total - Census families in private households'
# datadictionary['FM_CP'] == 'Total couple families by family structure and number of children'
# datadictionary['FM_CL'] == 'Common-law couples:'
# datadictionary['FM_CH'] == 'Total number of children at home'
# datadictionary['FM_AVCH'] == 'Average number of children at home per census family'
# datadictionary['FM_PH_P'] == 'Total number of persons in private households by living arrangements'
# datadictionary['FM_NF_P'] == 'Number of non-family persons'

# %% [markdown]
# 2nd Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Household', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: 'Household' + ' ' + x if 'household' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 0       HH_TOT  Total - Private households by household size. ...     788
# 1        HH_1P                                 Household 1 person      10
# 2        HH_2P                                Household 2 persons      11
# 3        HH_3P                                Household 3 persons      11
# 4        HH_4P                                Household 4 persons      11
# 5        HH_5P                        Household 5 or more persons      19
# 6   HH_NUMPINH            Number of persons in private households      39
# 7   HH_AVGPINH    Average number of persons in private households      47
# 8     HH_TOTHH  Total - Private households by household type,:...     705
# 9   HH_ONEFMHH  One-family households: It refers to a single c...     138
# 10    HH_CP_NC      Household Without children in a census family      39
# 11    HH_CP_CH         Household With children in a census family      36
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# HH_TOT
# Total - Private households by household size. A private household is a person or a group of persons, who occupy the same private dwelling unit,  share household expenditure and do not have a usual place of residence elsewhere in Canada. It may consist of a family group (census family) with or without other non-family persons, of two or more families sharing a dwelling, of a group of unrelated  persons (for example house staff),  or  of  one  person  living  alone.  Household  members  who  are  temporarily  absent   are  considered  as  part  of  their  usual  household.  Every person is a member of one and only one household. Communal and establishment accommodation are not taken as households. Households with several domiciles may be counted several times under circumstances.
#
# HH_TOTHH
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# HH_TOT
# Total - Private households by household size. A private household is a person or a group of persons, who occupy the same private dwelling unit,  share household expenditure and do not have a usual place of residence elsewhere in Canada. It may consist of a family group (census family) with or without other non-family persons, of two or more families sharing a dwelling, of a group of unrelated  persons (for example house staff),  or  of  one  person  living  alone.  Household  members  who  are  temporarily  absent   are  considered  as  part  of  their  usual  household.  Every person is a member of one and only one household. Communal and establishment accommodation are not taken as households. Households with several domiciles may be counted several times under circumstances.
#
# HH_TOTHH
# Total - Private households by household type,
#
# HH_ONEFMHH
# One-family households
#
# HH_MULFMHH
# Multiple-family households
#
# HH_NOFMHH
# Non-family households
#
# HH_TOT_A
# ...

# %%
datadictionary['HH_TOT'] = 'Total - Private households by household size'
datadictionary['HH_TOT_A'] = 'Total -  Owner and tenant households with household total income greater than zero'

# %% [markdown]
# 3rd Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Dwelling', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#      Variable                                        Description  length  \
# 0      DW_TOT  Total - Occupied private dwellings by structur...      65
# 1   DW_SINGLE  Single-detached house: A single dwelling not a...     228
# 2    DW_APT5_  Apartment, building that has five or more stor...     134
# 3       DW_OT                            Other attached dwelling      25
# 4     DW_SEMI  Semi-detached house: One of two dwellings atta...     304
# ..        ...                                                ...     ...
# 63  DW_MVALUE                      Median value of dwellings ($)      32
# 64  DW_AVALUE  Average value of dwelling $: Refers to the dol...     961
# 65  DW_MINVAL                     Minimum value of dwellings ($)      33
# 66  DW_MAXVAL                     Maximum value of dwellings ($)      33
# 67  DW_VALSTD  Standard deviation (dispersion) of dwelling va...      69
#
#                                   Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# DW_SINGLE
# Single-detached house: A single dwelling not attached to any other dwelling or structure (except its own garage or shed). A single - detached house has open space on all sides, and has no dwellings either above it or below it.
#
# DW_APT5_
# Apartment, building that has five or more storeys: A dwelling unit in a high-rise apartment building which has five or more storeys.
#
# DW_SEMI
# Semi-detached house: One of two dwellings attached side by side (or back to front) to each other, but not to any other dwelling or structure (except its own garage or shed). A semidetached dwelling has no dwellings either above it or below it, and the two units together have open space on all sides.
#
# DW_ROW
# Row house: One of three or more dwellings joined side by side (or occasionally side to back), such as a town house or garden home, but not having any other dwellings either above or below.
#
# DW_DUP
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# DW_SINGLE
# Single-detached house
#
# DW_APT5_
# Apartment, building that has five or more storeys
#
# DW_SEMI
# Semi-detached house
#
# DW_ROW
# Row house
#
# DW_DUP
# Apartment, detached duplex
#
# DW_APT_5
# Apartment, building that has fewer than five storeys
#
# DW_OT_SING
# Other single-attached house
#
# DW_MOVA
# Movable dwelling
#
# DW_TOTDWL6
# Total - Occupied private dwellings by condominium status.  A condominium is a residential complex in which dwellings are owned individually while land and common elements are held in joint ownership with others.
#
# DW_TOTDWL4
# ...

# %%
datadictionary['DW_TOTDWL6'] = 'Total - Occupied private dwellings by condominium status'
datadictionary['DW_TOTDWL4'] = 'Total - Occupied private dwellings by number of bedrooms'
datadictionary['DW_TOTDWLA'] = 'Total - Private households by housing suitability'
datadictionary['DW_TOTDWLG'] = 'Total- Occupied private dwellings by dwelling condition'
datadictionary['DW_TOTDWL7'] = 'Total - Private households by number of household maintainers'

# %% [markdown]
# 4th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Education', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
def temp(x,y):
    if '15' in y:
        return 'population aged 15 years and over: ' + x
    elif '15' in y:
        return 'population aged 15 - 24 years: ' + x
    elif '15' in y:
        return 'population aged 25 - 64 years: ' + x
    else:
        return x

# %%
df['Description'] = df.apply(lambda x: temp(x.Description, x.Variable), axis=1)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 1      ED_15HL  population aged 15 years and over: Total - Hig...     110
# 2      ED_15NC  population aged 15 years and over: No certific...      35
# 3     ED_15HSC  population aged 15 years and over: Secondary (...      60
# 4     ED_15POS  population aged 15 years and over: Postseconda...      46
# 5     ED_15TRC  population aged 15 years and over: Apprentices...      51
# ..         ...                                                ...     ...
# 105    ED_LOCC       Postsecondary certificate, diploma or degree      46
# 106  ED_CANADA                    Location of study inside Canada      35
# 107  ED_SAMEPR         Same as province or territory of residence      48
# 108    ED_OTPR  Different than province or territory of residence      55
# 109  ED_OUTCAN                   Location of study outside Canada      36
#
#                                    Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 120].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# ED_MJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households. It is collected for the highest certificate, diploma or degree above the high school or secondary school level
#
# ED_FMJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households - Female
#
# ED_MMJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households - Male
#
# ED_15LOC
# population aged 15 years and over: Total - Location of study compared with province or territory of residence with countries outside Canada for the population aged 15 years and over in private households

# %%
for feat in df[df.length > 120].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# ED_MJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households. It is collected for the highest certificate, diploma or degree above the high school or secondary school level
#
# ED_FMJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households - Female
#
# ED_MMJ
# Total - Major field of study - Classification of Instructional Programs (CIP) 2016 for the population aged 15 years and over in private households - Male
#
# ED_15LOC
# population aged 15 years and over

# %% [markdown]
# 5th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Minority', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x + ' '+ 'Population' if 'population' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 0       MN_TOT  Total - Visible minority for the population in...     184
# 1       MN_VIS                  Total visible minority population      35
# 2    MN_SASIAN                             South Asian Population      15
# 3   MN_CHINESE                                 Chinese Population      11
# 4     MN_BLACK                                   Black Population       9
# 5   MN_FILIPIN                                Filipino Population      12
# 6     MN_LAMER                          Latin American Population      18
# 7     MN_ARAB_                                    Arab Population       8
# 8   MN_SEASIA_                         Southeast Asian Population      19
# 9    MN_WASIAN                              West Asian Population      14
# 10   MN_KOREAN                                  Korean Population      10
# 11   MN_JAPANE                                Japanese Population      12
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# MN_TOT
# Total - Visible minority for the population in private households.  Visible minorities are persons, other than Aboriginal peoples, who are non-Caucasian in race or non-white in colour.
#
# MN_NIE
# Visible minority, n.i.e. Includes respondents who reported a write-in response classified as a visible minority such as 'Polynesian', 'Guyanese', 'Mauritian', etc. Population
#
# MN_MULT
# Multiple visible minorities. Includes respondents who reported more than one visible minority group by checking two or more mark-in circles, e.g. 'Black' and 'South Asian'. Population
#
# MN_OT
# Not a visible minority.  Includes respondents who reported 'Yes' to  Aboriginal (self-reporting) as well as respondents who were not considered to be members of a visible minority group. Population

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# MN_TOT
# Total - Visible minority for the population in private households.  Visible minorities are persons, other than Aboriginal peoples, who are non-Caucasian in race or non-white in colour.
#
# MN_NIE
# Visible minority, n.i.e. Includes respondents who reported a write-in response classified as a visible minority such as 'Polynesian', 'Guyanese', 'Mauritian', etc. Population
#
# MN_MULT
# Multiple visible minorities. Includes respondents who reported more than one visible minority group by checking two or more mark-in circles, e.g. 'Black' and 'South Asian'. Population
#
# MN_OT
# Not a visible minority.  Includes respondents who reported 'Yes' to  Aboriginal (self-reporting) as well as respondents who were not considered to be members of a visible minority group. Population

# %% [markdown]
# 6th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Immigration', header = 1)

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split('.')[0])

# %%
df
# Out:
#        Variable                                        Description  length  \
# 0       IM_TOT2  Total - Citizenship for the population in priv...     219
# 1        IM_CAN  Canadian citizens.  Includes those who reporte...      86
# 2     IM_CAN_18                    Canadian citizens aged under 18      35
# 3     IM_CAN18_                 Canadian citizens aged 18 and over      38
# 4         IM_OT                              Not Canadian citizens      23
# ..          ...                                                ...     ...
# 150     IM_PRIN                               Principal applicants      24
# 151      IM_SEC                               Secondary applicants      24
# 152     IM_SPON                     Immigrants sponsored by family      32
# 153  IM_REFUGEE                                           Refugees      10
# 154    IM_OTHER                                   Other immigrants      18
#
#                                    Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# IM_TOT2
# Total - Citizenship for the population in private households. Citizenship can be by birth or naturalization. A person may have more than one citizenship. A person may be stateless, that is, they may have no citizenship.
#
# IM_TOT
# Total - Immigrant status and period of immigration for the population in private households. Period of immigration refers to the period in which the immigrant first obtained his or her landed immigrant/permanent resident status. A landed immigrant/permanent resident refers to a person who has been granted the right to live permanently in Canada by immigration authorities.
#
# IM_CNTRY
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# IM_TOT2
# Total - Citizenship for the population in private households
#
# IM_TOT
# Total - Immigrant status and period of immigration for the population in private households
#
# IM_CNTRY
# Immigrants
#
# IM_NPRES
# Non-permanent residents
#
# IM_TOTAGE
# Total - Age at immigration for the immigrant population in private households
#
# IM_SUK
# United Kingdom
#
# IM_SRECENT
# Total - Selected places of birth for the recent immigrant population in private households
#
# IM_TOTGEN
# Total - Generation status for the population in private households
#
# IM_GEN2
# Second generation
#
# IM_GEN3
# Third generation or more
#
# IM_CAT
# Total - Admission category and applicant type for the immigrant population in private households who landed after 1980

# %% [markdown]
# 7th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Home Language', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#        Variable                                        Description Data Set  \
# 1        HL_TOT  Total - Language spoken most often at home for...   pc_hl1
# 2     HL_SINGLE                                   Single responses   pc_hl1
# 3    HL_OFFICIA                                 Official languages   pc_hl1
# 4    HL_ENGLISH                                            English   pc_hl1
# 5     HL_FRENCH                                             French   pc_hl1
# ..          ...                                                ...      ...
# 265    HL_MULTI                                 Multiple responses   pc_hl2
# 266       HL_EF                                 English and French   pc_hl2
# 267      HL_ENO                  English and non-official language   pc_hl2
# 268      HL_FNO                   French and non-official language   pc_hl2
# 269     HL_EFNO          English, French and non-official language   pc_hl2
#
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# HL_TOT
# Total - Language spoken most often at home for the total population excluding institutional residents

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# HL_TOT
# Total - Language spoken most often at home for the total population excluding institutional residents

# %% [markdown]
# 8th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Occupation', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#      Variable                                        Description  length  \
# 1      OC_TOT  Total labour force population aged 15 years an...      53
# 2       OC_NA                        Occupation - not applicable      29
# 3      OC_ALL                                    All occupations      17
# 4       OC_MG                           0 Management occupations      28
# 5       OC_BS  1 Business, finance and administration occupat...      54
# 6       OC_SC  2 Natural and applied sciences and related occ...      58
# 7       OC_HL                               3 Health occupations      24
# 8      OC_SSC  4 Occupations in education, law and social, co...      81
# 9      OC_ART  5 Occupations in art, culture, recreation and ...      55
# 10     OC_SAL                    6 Sales and service occupations      35
# 11      OC_TR  7 Trades, transport and equipment operators an...      71
# 12      OC_UN  8 Natural resources, agriculture and related p...      71
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')

# %% [markdown]
# 9th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Ethnicity', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#      Variable                                        Description Data Set  \
# 1    ET_TOT_A  Total - Aboriginal identity for the population...   pc_et1
# 2      ET_ABO  Aboriginal identity. Refers to those persons w...   pc_et1
# 3     ET_ABOS                        Single Aboriginal responses   pc_et1
# 4      ET_NAS              First Nations (North American Indian)   pc_et1
# 5    ET_METIS                                              Métis   pc_et1
# ..        ...                                                ...      ...
# 309   ET_HAWA                                           Hawaiian   pc_et2
# 310   ET_MAOR                                              Maori   pc_et2
# 311   ET_POLY                                 Polynesian, n.o.s.   pc_et2
# 312   ET_SAMO                                             Samoan   pc_et2
# 313   ET_PACI                    Pacific Islands origins, n.i.e.   pc_et2
#
#      length                                Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# ET_TOT_A
# Total - Aboriginal identity for the population in private households.
# It represents the total population of Canada, excluding institutional residents. It also represents the sum of persons who reported single ethnic origins and multiple ethnic origins in the census.
#
# ET_ABO
# Aboriginal identity. Refers to those persons who reported identifying with at least one Aboriginal group, i.e. North American Indian, Métis or Inuit (Eskimo), and/or those who reported being a Treaty Indian or a Registered Indian as defined by the Indian Act of Canada and/or who were members of an Indian Band or First Nation.  Included in the Aboriginal population are those persons who reported identifying with at least one Aboriginal group, that is, 'North American Indian', 'Métis' or 'Inuit (Eskimo)', and/or who reported being a Treaty Indian or a Registered Indian, as defined by the Indian Act of Canada, and/or who reported they were members of an Indian Band or First Nation.
#
# ET_ABOOT
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# ET_TOT_A
# Total - Aboriginal identity for the population in private households.
# It represents the total population of Canada, excluding institutional residents. It also represents the sum of persons who reported single ethnic origins and multiple ethnic origins in the census.
#
# ET_ABO
# Aboriginal identity. Refers to those persons who reported identifying with at least one Aboriginal group, i.e. North American Indian, Métis or Inuit (Eskimo), and/or those who reported being a Treaty Indian or a Registered Indian as defined by the Indian Act of Canada and/or who were members of an Indian Band or First Nation.  Included in the Aboriginal population are those persons who reported identifying with at least one Aboriginal group, that is, 'North American Indian', 'Métis' or 'Inuit (Eskimo)', and/or who reported being a Treaty Indian or a Registered Indian, as defined by the Indian Act of Canada, and/or who reported they were members of an Indian Band or First Nation.
#
# ET_ABOOT
# ...

# %%
datadictionary['ET_TOT_A'] = 'Total - Aboriginal identity for the population in private households'
datadictionary['ET_ABO'] = 'Aboriginal identity. Refers to those persons who reported identifying with at least one Aboriginal group'
datadictionary['ET_ABOOT'] = 'Aboriginal responses not included elsewhere'
datadictionary['ET_TOT'] = 'Total - Ethnic origin for the population in private households'

# %% [markdown]
# 10th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Labor Force', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: 'Population aged 15 years and over' + ' ' + x if 'population' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split('.')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 1       LF_15P  Population aged 15 years and over Total - Popu...      64
# 2        LF_15  Population aged 15 years and over In the labou...      21
# 3     LF_15EMP         Population aged 15 years and over Employed      12
# 4     LF_15UEM  Population aged 15 years and over Unemployed. ...     299
# 5     LF_15NOT  Population aged 15 years and over Not in the l...     282
# ..         ...                                                ...     ...
# 143  LF_MINHEA  Population aged 15 years and over 62 Health ca...      40
# 144  LF_MINART  Population aged 15 years and over 71 Arts, ent...      41
# 145  LF_MINACC  Population aged 15 years and over 72 Accommoda...      38
# 146  LF_MINOTH  Population aged 15 years and over 81 Other ser...      52
# 147  LF_MINPUB  Population aged 15 years and over 91 Public ad...      28
#
#                                    Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# LF_15UEM
# Population aged 15 years and over Unemployed.  Unemployed persons are those who
# a) were on temporary layoff with the expectation of recall and were available for work; or
# b) were without work, had actively looked for work, and were available for work ; or
# c) had a new job to start within four weeks, and were available for work.
#
# LF_15NOT
# Population aged 15 years and over Not in the labour force.  Refers to persons who were neither employed nor unemployed. It includes students, homemakers, retired workers, seasonal workers in an 'off' season who were not looking for work, and persons who could not work because of a long term illness or disability.
#
# LF_1524UEM
# Population aged 15 years and over Unemployed.  Unemployed persons are those who
# a) were on temporary layoff with the expectation of recall and were available for work; or
# b) were without work, had actively looked for work, and were available for work ; or
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# LF_15UEM
# Population aged 15 years and over Unemployed
#
# LF_15NOT
# Population aged 15 years and over Not in the labour force
#
# LF_1524UEM
# Population aged 15 years and over Unemployed
#
# LF_1524NOT
# Population aged 15 years and over Not in the labour force: Refers to persons who were neither employed nor unemployed
#
# LF_25UEM
# Population aged 15 years and over Unemployed
#
# LF_25NOT
# Population aged 15 years and over Not in the labour force: Refers to persons who were neither employed nor unemployed
#
# LF_INTOT
# Total Labour Force population aged 15 years and over by Industry - North American Industry Classification System (NAICS) 2012
#
# LF_FINTOT
# Total Labour Force population aged 15 years and over by Industry - North American Industry Classification System (NAICS) 2012 -  Female
#
# LF_MINTOT
# Total Labour Force population aged 15 years and over by Industry - North American Industry Classification System (NAICS) 2012 - Male

# %% [markdown]
# 11th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Employment', header = 1)

# %%
df = df.iloc[2:,:]

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
# df['Description'] = df['Description'].apply(lambda x: 'Population aged 15 years and over' + ' ' + x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split(':')[0])

# %%
df
# Out:
#       Variable                                        Description  length  \
# 2       EM_TOT  Total labour force aged 15 years and over by c...      60
# 3        EM_NA  Class of worker - not applicable. Unemployed p...     150
# 4       EM_ALL  All classes of workers. Refers to the experien...     145
# 5       EM_PEM                                           Employee      12
# 6       EM_PSM                                      Self-employed      17
# ..         ...                                                ...     ...
# 94     EM_NOAB                                     Non-Aboriginal      18
# 95  EM_LGENFRA                                 English and French      20
# 96  EM_LGENNOA                  English and non-official language      35
# 97  EM_LGFRNOA                   French and non-official language      34
# 98  EM_LGEFNOA          English, French and non-official language      43
#
#                                   Description-1stpart
# ...

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# EM_NA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_ALL
# All classes of workers. Refers to the experienced labour force population: persons who are employed or who worked for pay or in self-employment
#
# EM_FNA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_FALL
# All classes of workers. Refers to the experienced labour force population: persons who are employed or who worked for pay or in self-employment
#
# EM_MNA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_MALL
# All classes of workers. Refers to the experienced labour force population: persons who are employed or who worked for pay or in self-employment
#
# EM_PLTOT
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# EM_NA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_ALL
# All classes of workers. Refers to the experienced labour force population
#
# EM_FNA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_FALL
# All classes of workers. Refers to the experienced labour force population
#
# EM_MNA
# Class of worker - not applicable. Unemployed persons 15 years and over who have never worked for pay or in self-employment or who had worked before.
#
# EM_MALL
# All classes of workers. Refers to the experienced labour force population
#
# EM_PLTOT
# Total - Place of work status for the employed labour force aged 15 years and over in private households.
# ...

# %%
datadictionary['EM_PLTOT'] = 'Total - Place of work status for the employed labour force aged 15 years and over in private households.'

# %% [markdown]
# 11th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Income', header = 1)

# %%
df = df.iloc[2:,:]

# %%
df
# Out:
#                 Variable                                        Description  \
# 2                IN_P15_  Total - Total income groups for the population...
# 3                IN_N15_                               Without total income
# 4                IN_W15_                                  With total income
# 5                IN_P_05                     Under $10,000 (including loss)
# 6               IN_P1020                                 $10,000 to $19,999
# ..                   ...                                                ...
# 405              IN_T2PH      Total - Household income for two-or-more-p...
# 406              IN_M2PH        Median total income of two-or-more-perso...
# 407              INTM2PH        Median after-tax income of two-or-more-p...
# 408              IN_A2PH        Average total income of two-or-more-pers...
# 409              INTA2PH        Average after-tax income of two-or-more-...
#
#     Data Set
# 2     pc_in1
# 3     pc_in1
# ...

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: str(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: 'Household' + ' ' + x if 'household' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split('.')[0])

# %%
df
# Out:
#      Variable                                        Description Data Set  \
# 2     IN_P15_  Total - Total income groups for the population...   pc_in1
# 3     IN_N15_                     Household Without total income   pc_in1
# 4     IN_W15_                        Household With total income   pc_in1
# 5     IN_P_05           Household Under $10,000 (including loss)   pc_in1
# 6    IN_P1020                       Household $10,000 to $19,999   pc_in1
# ..        ...                                                ...      ...
# 405   IN_T2PH  Total - Household income for two-or-more-perso...   pc_in2
# 406   IN_M2PH  Median total income of two-or-more-person hous...   pc_in2
# 407   INTM2PH  Median after-tax income of two-or-more-person ...   pc_in2
# 408   IN_A2PH  Average total income of two-or-more-person hou...   pc_in2
# 409   INTA2PH  Average after-tax income of two-or-more-person...   pc_in2
#
#      length                                Description-1stpart
# ...

# %%
df = df.dropna()

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')
# Out:
# IN_EP15_
# Total - Employment income groups for the population aged 15 years and over in private households.
# Employment income includes wages, salaries and commissions, net self-employment income from farm or non-farm unincorporated business and/or professional practice.
#
# IN_TFP15_
# Total - After-tax income groups for the population aged 15 years and over in private households - Female
#
# IN_EFP15_
# Total - Employment income groups for the population aged 15 years and over in private households - Female
#
# IN_TMP15_
# Total - After-tax income groups for the population aged 15 years and over in private households - Male
#
# IN_EMP15_
# Total - Employment income groups for the population aged 15 years and over in private households - Male
#
# IN_PMAR
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')
# Out:
# IN_EP15_
# Total - Employment income groups for the population aged 15 years and over in private households
#
# IN_TFP15_
# Total - After-tax income groups for the population aged 15 years and over in private households - Female
#
# IN_EFP15_
# Total - Employment income groups for the population aged 15 years and over in private households - Female
#
# IN_TMP15_
# Total - After-tax income groups for the population aged 15 years and over in private households - Male
#
# IN_EMP15_
# Total - Employment income groups for the population aged 15 years and over in private households - Male
#
# IN_PMAR
# Household Market income (%)
#
# IN_PGOV
# Household Government transfers (%)
#
# IN_WE15_F
# Number of employment income recipients aged 15 years and over in private households who worked full year full time
#
# IN_FPCOMP
# Composition of total income of the population aged 15 years and over in private households (%) - Female
#
# IN_FWE15_F
# ...

# %% [markdown]
# 12th Tab

# %%
df = pd.read_excel('Data Dictionary SuperDemographics 2020.xlsx',sheet_name = 'Religion', header = 1)

# %%
df = df.iloc[1:,:]

# %%
df
# Out:
#              Variable                                        Description
# 1              RL_TOT  Total population in private households by reli...
# 2              RL_BUD                                           Buddhist
# 3             RL_CHRI                                          Christian
# 4             RL_ANGL                                           Anglican
# 5              RL_BAP                                            Baptist
# 6             RL_CATH                                           Catholic
# 7             RL_ORTH                                 Christian Orthodox
# 8              RL_LUT                                           Lutheran
# 9             RL_PENT                                        Pentecostal
# 10            RL_PRES                                       Presbyterian
# 11          RL_UNITED                                      United Church
# 12            RL_OTCH                                    Other Christian
# ...

# %%
df['length'] = df['Description'].apply(lambda x: len(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: str(x))

# %%
df['Variable'] = df['Variable'].apply(lambda x: x.strip())
df['Description'] = df['Description'].apply(lambda x: x.strip())
# df['Description'] = df['Description'].apply(lambda x: 'Household' + ' ' + x if 'household' not in x else x)

# %%
df['Description-1stpart'] = df['Description'].apply(lambda x: x.split('.')[0])

# %%
df
# Out:
#      Variable                                        Description  length  \
# 1      RL_TOT  Total population in private households by reli...      50
# 2      RL_BUD                                           Buddhist      10
# 3     RL_CHRI                                          Christian      11
# 4     RL_ANGL                                           Anglican      12
# 5      RL_BAP                                            Baptist      11
# 6     RL_CATH                                           Catholic      12
# 7     RL_ORTH                                 Christian Orthodox      22
# 8      RL_LUT                                           Lutheran      12
# 9     RL_PENT                                        Pentecostal      15
# 10    RL_PRES                                       Presbyterian      16
# 11  RL_UNITED                                      United Church      17
# 12    RL_OTCH                                    Other Christian      19
# ...

# %%
df = df.dropna()

# %%
for value in df[df.length < 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description'].item()
for value in df[df.length > 100].Variable.values:
    datadictionary[value] = df[df.Variable == value]['Description-1stpart'].item()

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description'].item())
    print('')

# %%
for feat in df[df.length > 100].Variable.tolist():
    print(feat)
    print(df[df['Variable'] == feat]['Description-1stpart'].item())
    print('')

# %%
datadictionary
# Out:
# {'PP_TOT': 'Total - Age groups and average age of the population',
#  'PP_0_14': 'Population 0 to 14 years',
#  'PP_0_4': 'Population 0 to 4 years',
#  'PP_5_9': 'Population 5 to 9 years',
#  'PP_10_14': 'Population 10 to 14 years',
#  'PP_15_64': 'Population 15 to 64 years',
#  'PP_15_19': 'Population 15 to 19 years',
#  'PP_20_24': 'Population 20 to 24 years',
#  'PP_25_29': 'Population 25 to 29 years',
#  'PP_30_34': 'Population 30 to 34 years',
#  'PP_35_39': 'Population 35 to 39 years',
#  'PP_40_44': 'Population 40 to 44 years',
#  'PP_45_49': 'Population 45 to 49 years',
#  'PP_50_54': 'Population 50 to 54 years',
#  'PP_55_59': 'Population 55 to 59 years',
#  'PP_60_64': 'Population 60 to 64 years',
#  'PP_65_': 'Population 65 years and over',
#  'PP_65_69': 'Population 65 to 69 years',
#  'PP_70_74': 'Population 70 to 74 years',
#  'PP_75_79': 'Population 75 to 79 years',
#  'PP_80_84': 'Population 80 to 84 years',
#  'PP_85': 'Population 85 years and over',
# ...

# %%
import pickle

# %%
file_to_write = open("datadictionary.pickle", "wb")
pickle.dump(datadictionary, file_to_write)
